# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Problem 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,12))

ax.grid(True, which='both')
# ax.axhline(y=0, color='k')
# ax.axvline(x=0, color='k')

ax.hlines(y=-50, xmin=0.0, xmax=150.0, color='b',lw=3)
ax.hlines(y=0, xmin=250, xmax=500, color='b',lw=3)

ax.vlines(x=150, ymin=-100, ymax=100.0, color='r',lw=3)
ax.vlines(x=250, ymin=-100, ymax=100, color='r',lw=3)
ax.vlines(x=400, ymin=0, ymax=100, color='r',lw=3)

ax.text(s='R_1', x=75, y=-75, fontsize='x-large')
ax.text(s='R_2', x=75, y=25, fontsize='x-large')
ax.text(s='R_3', x=200, y=0, fontsize='x-large')
ax.text(s='R_4', x=387.5, y=-50, fontsize='x-large')
ax.text(s='R_5', x=312.5, y=50, fontsize='x-large')
ax.text(s='R_6', x=450, y=50, fontsize='x-large')

ax.set_xlim(0, 500)
ax.set_ylim(-100,100)

ax.set_xlabel(r'X_1', fontsize='x-large')
ax.set_ylabel(r'X_2', fontsize='x-large')
ax.set_title('Example Tree partition of a 2D feature space', fontsize='xx-large')

plt.savefig('q1_tree_partition.png')

# %%
## Problem 4 part b
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,12))

ax.grid(True, which='both')
# ax.axhline(y=0, color='k')
# ax.axvline(x=0, color='k')

ax.hlines(y=2, xmin=-1, xmax=3, color='b',lw=3)
ax.hlines(y=1, xmin=-1, xmax=3, color='b',lw=3)

ax.vlines(x=0, ymin=1, ymax=2, color='r',lw=3)
ax.vlines(x=1, ymin=-1, ymax=1, color='r',lw=3)

ax.text(s='2.49', x=1, y=2.5, fontsize='x-large')
ax.text(s='-1.06', x=-0.5, y=1.5, fontsize='x-large')
ax.text(s='0.21', x=1.5, y=1.5, fontsize='x-large')
ax.text(s='-1.80', x=0, y=0, fontsize='x-large')
ax.text(s='0.63', x=2, y=0, fontsize='x-large')

ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)

ax.set_xlabel(r'X_1', fontsize='x-large')
ax.set_ylabel(r'X_2', fontsize='x-large')
ax.set_title('Tree partition of 2D feature space', fontsize='xx-large')

plt.savefig('q4_tree_partition.png')
# Out:
# Text(0.5, 1.0, 'Tree partition of 2D feature space')
