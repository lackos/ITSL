# %%
    import pandas as pd
    import numpy as np 
    import matplotlib.pyplot as plt
    import seaborn as sns
    import os

# %%
wage_df = pd.read_csv('../Data/wage.csv')
X = wage_df['age']
y = wage_df['wage']

# %%
## Problem 3

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
x_1 = np.arange(-2,1,0.01)
x_2 = np.arange(1,2,0.01)
y_1 = 1 + x_1
y_2 = -2*x_2**2 + 3*x_2 -1
ax.plot(x_1, y_1, color='b')
ax.plot(x_2, y_2, color = 'b')

ax.set_ylabel('y')
ax.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
x_1 = np.arange(-2,1,0.01)
x_2 = np.arange(1,2,0.01)
x_3 = np.arange(2,3,0.01)
x_4 = np.arange(3,4,0.01)
x_5 = np.arange(4,5,0.01)
y_1 = 2*np.ones(x_1.shape)
y_2 = x_2 + 2
y_3 = 1*np.ones(x_3.shape)
y_4 = 3*x_4 - 8
y_5 = 4*np.ones(x_5.shape)
ax.plot(x_1, y_1, color='b')
ax.plot(x_2, y_2, color = 'b')
ax.plot(x_3, y_3, color='b')
ax.plot(x_4, y_4, color = 'b')
ax.plot(x_5, y_5, color='b')

ax.set_ylabel('y')
ax.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')
